# %%
import pandas as pd

# To enable importing of jupyter notebook A into notebook B:
import import_ipynb 
import Advanced_EDA_ISK_Jup as my_EDA     #  To import 'Advanced_EDA_ISK_Jup.ipynb'
# Out:
# importing Jupyter notebook from Advanced_EDA_ISK_Jup.ipynb
# importing Jupyter notebook from colorsStyles_displayOptions_Jup.ipynb

# %% [markdown]
# # Read dataset:

# %%
# my_df = pd.read_csv("diamonds.csv", index_col=0 )
my_df = pd.read_csv("san francisco crimes.csv", index_col=0 )

# %% [markdown]
# # Create an instance of Advanced_EDA class for current dataframe:

# %%
my_df_eda = my_EDA.Advanced_EDA(df=my_df)

# %% [markdown]
# ## Examples to use methods of Advanced_EDA class:

# %%
my_df_eda.Df_Get_Samples(samples_num=3)
# Out:
# Random 3 samples:
#                           Category                Descript DayOfWeek PdDistrict     Resolution                   Address         X        Y
# Dates
# 2014-10-19 21:16:00  LARCENY/THEFT     PETTY THEFT BICYCLE    Sunday   SOUTHERN           NONE          3RD ST / KING ST -122.3918  37.7781
# 2005-09-08 10:38:00  LARCENY/THEFT  GRAND THEFT PICKPOCKET  Thursday  INGLESIDE           NONE  MISSION ST / LAWRENCE AV -122.4509  37.7094
# 2006-02-12 07:10:00        ASSAULT                 BATTERY    Sunday    MISSION  ARREST, CITED  1000 Block of POTRERO AV -122.4065  37.7565

# %%
my_df_eda.Df_get_basic_info()
# Out:
# Dimensionality of the df: (878049, 8)
#
# Columns:Index(['Category', 'Descript', 'DayOfWeek', 'PdDistrict', 'Resolution', 'Address', 'X', 'Y'], dtype='object')
#
# Index name ': Dates'
# Index is Unique = False
# Index type: object
# ## If the Index is NOT Unique => check it's duplicates!! ##
#
# Data describtion:
#                count unique                           top    freq   mean      std    min    25%    50%    75%    max
# Category      878049     39                 LARCENY/THEFT  174900    NaN      NaN    NaN    NaN    NaN    NaN    NaN
# Descript      878049    879  GRAND THEFT FROM LOCKED AUTO   60022    NaN      NaN    NaN    NaN    NaN    NaN    NaN
# DayOfWeek     878049      7                        Friday  133734    NaN      NaN    NaN    NaN    NaN    NaN    NaN
# PdDistrict    878049     10                      SOUTHERN  157182    NaN      NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
my_df_eda.Col_Detailed_Dtypes()
# Out:
# DETAILED COLUMNS TYPES:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 878049 entries, 2015-05-13 23:53:00 to 2003-01-06 00:01:00
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Category    878049 non-null  object
#  1   Descript    878049 non-null  object
#  2   DayOfWeek   878049 non-null  object
#  3   PdDistrict  878049 non-null  object
#  4   Resolution  878049 non-null  object
#  5   Address     878049 non-null  object
#  6   X           878049 non-null  float64
#  7   Y           878049 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 80.3+ MB
# None
# --------------------
# DTYPE SUMMARY:
#
# float_columns:
#  ['X', 'Y']
#
# Sring columns:
#  ['Category', 'Descript', 'DayOfWeek', 'PdDistrict', 'Resolution', 'Address']

# %% [markdown]
# ### Check number & percentages(%) of all Unique values ( with ot without 'None') :

# %%
my_df_eda.Val_Unique_per_column(without_None=True)
# Out:
# The Number of Unique values ( Without 'None'):
# Category         39
# Descript        879
# DayOfWeek         7
# PdDistrict       10
# Resolution       17
# Address       23228
# X             34243
# Y             34243
# dtype: int64
# The Percentages(%) of all Unique values ( Without 'None') from total num of observations:
# Category      0.0044
# Descript      0.1001
# DayOfWeek     0.0008
# PdDistrict    0.0011
# Resolution    0.0019
# Address       2.6454
# X             3.8999
# Y             3.8999
# dtype: float64

# %% [markdown]
# ### Check number and percentages(%) of Non-null values (with duplicates!) from total num of observations (per feature):

# %%
my_df_eda.Val_Missing_with_percents_per_column()
# Out:
# CHECKING MISSING VALUES:
# The Number of NULL values per feature:
# Category      0
# Descript      0
# DayOfWeek     0
# PdDistrict    0
# Resolution    0
# Address       0
# X             0
# Y             0
# dtype: int64
#
# The Percentages(%) of Non-null values (with duplicates!) from total num of observations (per feature):
# Category      100.0
# Descript      100.0
# DayOfWeek     100.0
# PdDistrict    100.0
# Resolution    100.0
# Address       100.0
# X             100.0
# Y             100.0
# dtype: float64
#
#  ##!In the next step CHECK DUPLICATE observations (per feature) => [ DUPLICATE observations = Total  observations - number of Unique values] ##

# %% [markdown]
# ### Check Missing values and Diversity of values.
# ### When 'col_name' is the Target Variable => check if data is Imbalanced:

# %%
my_df_eda.Val_Missing_and_Diversity_for_specific_feature(col_name='Category')
# Out:
# ANALYSIS OF VALUES IN ' Category ' COLUMN:
#
# The Total number of NON-None and Non-Unique in 'Category'column 'Category' =  878049
# The Percent(%) of NON-None and Non-Unique values in 'Category' column'Category' =  100.0
#
# The Diversity of values: )
# LARCENY/THEFT                  174900
# OTHER OFFENSES                 126182
# NON-CRIMINAL                    92304
# ASSAULT                         76876
# DRUG/NARCOTIC                   53971
# VEHICLE THEFT                   53781
# VANDALISM                       44725
# WARRANTS                        42214
# BURGLARY                        36755
# SUSPICIOUS OCC                  31414
# MISSING PERSON                  25989
# ROBBERY                         23000
# FRAUD                           16679
# FORGERY/COUNTERFEITING          10609
# SECONDARY CODES                  9985
# WEAPON LAWS                      8555
# PROSTITUTION                     7484
# TRESPASS                         7326
# ...

# %% [markdown]
# ### Display all duplicated rows with Specific Value in wanted column.
# #### If dropna=False => with None values. Othwerwise - without None

# %%
#CHECK DUPLICATES for specific value in wanted column:
wanted_column ='Category'
# checked_val=62.5
wanted_val='RUNAWAY'

my_df_eda.get_SubDF_of_duplicates_for_specificVal_in_specificCol(col_name=wanted_column, checked_val=wanted_val, \
                                                                 dropnav=False )
# Out:
# SUB-DF WITH VALUE ='RUNAWAY' IN COLUMN 'Category':
#
# Sub-dataframes shape: (1946, 8)
# 'Sub-dataframes describtion:'
#     count      mean     std       min       25%       50%       75%       max
# X  1946.0 -122.4322  0.0267 -122.5087 -122.4532 -122.4414 -122.4066 -122.3649
# Y  1946.0   37.7524  0.0247   37.7083   37.7286   37.7572   37.7717   37.8102
# 'Sample(5) of Sub-df:'
#                     Category Descript  DayOfWeek PdDistrict Resolution                  Address         X        Y
# Dates
# 2003-05-28 19:00:00  RUNAWAY  RUNAWAY  Wednesday    BAYVIEW    LOCATED    0 Block of LEDYARD ST -122.4021  37.7332
# 2007-06-30 12:00:00  RUNAWAY  RUNAWAY   Saturday   RICHMOND    LOCATED     600 Block of 32ND AV -122.4921  37.7769
# 2010-03-27 19:00:00  RUNAWAY  RUNAWAY   Saturday  INGLESIDE  UNFOUNDED  100 Block of PRECITA AV -122.4172  37.7472
# 2009-08-17 15:40:00  RUNAWAY  RUNAWAY     Monday    MISSION    LOCATED  900 Block of POTRERO AV -122.4066  37.7572
# ...

# %% [markdown]
# ### Very useful function!!!
# #### 1-Checks if values in wanted column are unique (including 'NaN')
#   It's important to check 'NaN' values, especially in situations when we have many empty values and some unique -
#   it will be mistake not to count NaN!
#
# #### 2-If values are Non-unique:
#      1) print sizes of groups (="group_size")
#      2) print values for 3 biggest groups (by "group_size") => top to down

# %%
my_df_eda.Val_IfUnique_or_print_top_gropSizes(col_name='Category', num_of_top_size_groups=5)
# Out:
# Category  has NON UNIQUE values
#
# All groups sizes:
#     group_size  num_of_diff_val_in_the_group
# 38      174900                             1
# 37      126182                             1
# 36       92304                             1
# 35       76876                             1
# 34       53971                             1
# 33       53781                             1
# 32       44725                             1
# 31       42214                             1
# 30       36755                             1
# 29       31414                             1
# 28       25989                             1
# 27       23000                             1
# 26       16679                             1
# 25       10609                             1
# 24        9985                             1
# 23        8555                             1
# 22        7484                             1
# 21        7326                             1
# 20        4540                             1
# ...

# %% [markdown]
# ### Sub-Dataframes Methods:

# %%
my_df_eda.get_SubDF_without_None_Val_for_specific_feature(col_name='Category')
# Out:
# The Percent (%) of 'None' values in column 'Category' =  0.0

# %% [markdown]
# ### Correlation with visualisation.
# #### With possibility to drop correlative features ( which correlation is greater than 'corr_threshold') from the orig_df:
# Threshold=90 => for datasets with a small number of columns
# Threshold=80 => for datasets with a small number of columns

# %%
my_df_eda.Corr_with_plot_Find_and_remove()
# Out:
# Correlation with plot func
# features_to_drop_list:
# []
# Lenth of 'features_to_drop_list' = 0

# %% [markdown]
# ## Create a ProfileReport for dataset.
# #### ProfileReport was written by Simon Brugman (https://github.com/pandas-profiling/pandas-profiling)

# %%
my_df_eda.Portf_Create( portf_name="san_francisco_crimes_Portfolio")
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-12-20 12:16:37.494832&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### Get variables that are rejected for Portfolio - analysis (e.g. constant, mixed data types):

# %%
# Returns : a set of column names that are unsupported by Portfolio's analysis:
my_df_eda.Portf_get_RegectedVariables(return_result = False )
# Out:
# Portfolio rejected variables:
# set()

# %% [markdown]
# ### Get a sub-dataframe with duplicate rows and their counts:

# %%
my_df_eda.Portf_get_Duplicates(return_result = False)
# Out:
# Portfolio duplicates (sub-df):
#                     Dates        Category                                   Descript  DayOfWeek  PdDistrict      Resolution                       Address         X        Y  count
# 1767  2013-10-18 15:00:00  OTHER OFFENSES                MISCELLANEOUS INVESTIGATION     Friday  TENDERLOIN            NONE          0 Block of POWELL ST -122.4078  37.7851     16
# 236   2004-07-07 10:00:00    NON-CRIMINAL                             FOUND PROPERTY  Wednesday    NORTHERN            NONE     1100 Block of FILLMORE ST -122.4321  37.7800     13
# 1555  2012-07-15 06:00:00        BURGLARY                   BURGLARY, FORCIBLE ENTRY     Sunday    SOUTHERN            NONE  0 Block of SOUTH VAN NESS AV -122.4183  37.7727     11
# 1445  2011-08-12 08:00:00    NON-CRIMINAL                             FOUND PROPERTY     Friday  TENDERLOIN            NONE          300 Block of EDDY ST -122.4129  37.7838     10
# ...

# %% [markdown]
# ### Check Correlation for other dataset:

# %%
# Read data:
df_diamonds = pd.read_csv("diamonds.csv", index_col=0 )

# %%
# Create an instance of Advanced_EDA class for current dataframe:
df_diamonds_eda = my_EDA.Advanced_EDA(df=df_diamonds)

# %%
df_diamonds_eda.Corr_with_plot_Find_and_remove( targetVal=None, 
                                                corr_threshold = 0.90, 
                                                remove_negative=False, 
                                                visualisation = True, 
                                                return_subdf_without_corr_features = False
                                              )
# Out:
# Correlation with plot func
# features_to_drop_list:
# []
# Lenth of 'features_to_drop_list' = 0
